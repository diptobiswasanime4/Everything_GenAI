# %% [markdown]
# ## Terminologies
#
# #### Corpus
# It is an essay.
# #### Documents
# It is the list of sentences from the essay.
# #### Words
# It is the list of words from a sentence (or essay)
# #### Tokens
# It is the list of sentences or words (tokens) from the essay

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize, wordpunct_tokenize

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dipto\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
corpus = """
The Hero, the King, and the Cook
"Tal, I'm so happy to see you here. I cannot thank you enough for saving my kingdom, we're all safe because of you. You're the true Hero!"
"Yeah it was a predicament for sure. Somebody had to do it. I did it. Haha"
"You're as cheerful as ever. Tal, I don't think it's enough, but in your honor I have decided to throw the biggest party you've ever seen. Eat, drink and party as much as you want, don't hesitate!"
"Cheers, for the kingdom, and for the king!"
The Hero and the King were seated side by side at the center of a giant hall, eating and drinking from a hundred dishes exhibited right in front of them in a giant table.
A lot of very very important people (VVIPs) were surrounding them, ministers, bureaucrats, priests, scholars, merchants, all trying to get a glimpse of the Hero, possibly talk to him. Everybody was in total awe, some even offered the hand of their daughter, the Hero was cheerful but unbothered.
Outside even the commoners were in a festive mood. They were all singing praises of the hero, and dancing. Many offered big discounts in their shops, while some hiked prices and bagged profits, all in the Hero's honor.
"Tal, what do you think? I bet, you've never been to a party as grand as this one before!"
"You bet! The others doesn't even look like parties now."
"The biggest surprise is not yet here. Everything you see now pales in comparison."
"Oh still something bigger is left?"
"Much much bigger, something you have never imagined!"
"Oh what could that be? I know, I know, the hand of the princess! Oh come on, I cannot settle down right now, I love being a hero, but since you insist, I will think on…"
"That's right, that's right, now is not really the time for you to settle, I have never seen a fine warrior like you before, you have plenty of time ahead, or do you want a big fat tummy like mine?"
"Haha and then I have to hire another Hero to save my kingdom, I can never let that happen! At least not before I tame a Dragon from the village of Dragon Tamers."
"Maybe I can fund your adventure over there, only bring me 3 Fire Dragons for my kingdom's protection."
"Sure sure. Why not? Anyway, I'm still curious, what is the big bang thing, that's coming next?"
"Here it is", the king directed Tal.
The Head Cook arrived, along with him came something grand. Everybody wondered, a secret dish? But it is covered. Everybody is curious. What could that be!?
"Tal, once again I'd like to take this opportunity to thank you, on behalf of the entire kingdom, on behalf of my entire 65 million subjects, for saving our lives from the Evil Twin-headed Dragon Dodura, that had been tormenting our kingdom for so long, even our beautiful capital city of Astral was losing her vibrance, she is now recovering. And it's all because of you."
Everybody looked at Tal. He was the center of undivided attention.
"I know words are not enough. So I wanted to give you this. The rarest and the most delicious fruit you'll find in the entire world. Fruit that doesn't rot in 100 years, that cures incurable diseases, also is unbelievably delicious, only those who have tasted can confirm. Only a handful of them, that our former Great General Snorz laid down his life to secure from the treacherous Southern islands, and this is the last one remaining."
Everybody listened to the king with awe. The king concluded, ordering the Head Cook to remove the cover.
"Tal, I want you to have it. Behold, the rarest of the rare, The Mystic Pomegranite!"
Everybody looked with complete attention as the Head Cook removed the cover. Then they were little bit startled. They were confused! Really? The king's face looked lifeless, stoic. Head Cook is silent. They were all looking at the plate. It's empty!
People at the back started gossiping.
"What happened!? What happened to the fruit?"
"Somebody stole the fruit! Really?"
"Mystic Pomegranite? A miracle fruit!? Never heard of it."
"The General laid down his life for a stupid fruit? I thought it was…"
"I'm sure it's the Head Cook. Look at his face. The fruit is so great, who wouldn't…"
"Feel so bad for The Hero. The king is…"
The king was looking at the plate with lifeless eyes. Now he looked at the crowd. He looked angry. The crowd became silent in an instant. The king moved his face towards the Head Cook, he's standing silent with eyes closed.
The Hero observed the whole situation. He felt awkward.
"Head Cook", the king called in a low deep voice.
"At your service, your Highness!"
"Please explain."
"Yes! Welcome Tal, my Hero, to our beautiful kingdom of Purplewoods, south of the beautiful Purplewoods Forest, ruled by his Majesty, the mighty king Thoros. In the name of his highness let me introduce you our kingdom's finest cuisine."
The king observed the situation, but stayed silent.
The Head Cook took a mug of wine. "The Purple Wine, made from the juice of the finest quality purple grapes, that you may have already started with, all made under my direct oversight. Then comes Fire Chicken, don't confuse this with regular chickens, they're the finest breed of chickens imported from the Western kingdoms, I have made it personally with my hands. Once you eat, you'll keep coming back. Then…"
"Silence", the king shouted at the Head Cook. Everybody in the hall had their faces pale in fear. The Hero was observing the whole situation, trying to be calm, but feeling awkward.
"Where is the Mystic Pomegranite!?"
The Head Cook stayed silent.
"It was your responsibility to keep it safe, and bring it for Tal. Where is it?"
The king's eyes turned blood-red. The crowd wondered about the situation, but scared to gossip about anything.
"Your Highness", the head cook said.
The king stared at him.
"I'm deeply saddened to see that the Wonder Fruit has gone missing. At your direction I will quickly direct the cooks to search for it", the head cook said in a calm and quiet tone. It was pretty apparent that he was trying to mock the king. But why!? Everybody wondered.
"What nonsense!? It's not only the cooks, I'll also direct the soldiers to search for it. Guards, search every nook and corner of the Castle and find the Miracle Fruit, the Mystic Pomegranite for our hero ASAP", the king directed. His voice echoed in the walls of the giant hall. The cooks and the guards immediately started moving around in search of the fruit. They were searching everywhere possible, in the kitchen, armory, bathhouse, below mats, behind furnitures and other decorations, some were also asking and searching people in the Castle. On the other hand the people who came to the Castle were all in a state of shock and panic. Everybody started talking, nobody's sure what's going on.
"Better I should also assist the young cooks in the Great Search", the head cook said as he wanted to go and search.
"Shut Up Head Cook! You're not going anywhere, unless I wish so", the king noticed the Head Cook's intent and stopped him immediately.
"At your service your Highness", the Cook said. He was surprisingly calm in such a tense situation.
"""

# %%
sentences = sent_tokenize(corpus)

sentences
# Out:
# ['\nThe Hero, the King, and the Cook\n"Tal, I\'m so happy to see you here.',
#  "I cannot thank you enough for saving my kingdom, we're all safe because of you.",
#  'You\'re the true Hero!"',
#  '"Yeah it was a predicament for sure.',
#  'Somebody had to do it.',
#  'I did it.',
#  'Haha"\n"You\'re as cheerful as ever.',
#  "Tal, I don't think it's enough, but in your honor I have decided to throw the biggest party you've ever seen.",
#  'Eat, drink and party as much as you want, don\'t hesitate!"',
#  '"Cheers, for the kingdom, and for the king!"',
#  'The Hero and the King were seated side by side at the center of a giant hall, eating and drinking from a hundred dishes exhibited right in front of them in a giant table.',
#  'A lot of very very important people (VVIPs) were surrounding them, ministers, bureaucrats, priests, scholars, merchants, all trying to get a glimpse of the Hero, possibly talk to him.',
#  'Everybody was in total awe, some even offered the hand of their daughter, the Hero was cheerful but unbothered.',
#  'Outside even the commoners were in a festive mood.',
#  'They were all singing praises of the hero, and dancing.',
#  "Many offered big discounts in their shops, while some hiked prices and bagged profits, all in the Hero's honor.",
#  '"Tal, what do you think?',
#  'I bet, you\'ve never been to a party as grand as this one before!"',
#  '"You bet!',
#  'The others doesn\'t even look like parties now."',
#  '"The biggest surprise is not yet here.',
#  'Everything you see now pales in comparison."',
#  '"Oh still something bigger is left?"',
#  '"Much much bigger, something you have never imagined!"',
#  '"Oh what could that be?',
#  'I know, I know, the hand of the princess!',
#  'Oh come on, I cannot settle down right now, I love being a hero, but since you insist, I will think on…"\n"That\'s right, that\'s right, now is not really the time for you to settle, I have never seen a fine warrior like you before, you have plenty of time ahead, or do you want a big fat tummy like mine?"',
#  '"Haha and then I have to hire another Hero to save my kingdom, I can never let that happen!',
#  'At least not before I tame a Dragon from the village of Dragon Tamers."',
#  '"Maybe I can fund your adventure over there, only bring me 3 Fire Dragons for my kingdom\'s protection."',
#  '"Sure sure.',
#  'Why not?',
#  'Anyway, I\'m still curious, what is the big bang thing, that\'s coming next?"',
#  '"Here it is", the king directed Tal.',
#  'The Head Cook arrived, along with him came something grand.',
#  'Everybody wondered, a secret dish?',
#  'But it is covered.',
#  'Everybody is curious.',
#  'What could that be!?',
#  '"Tal, once again I\'d like to take this opportunity to thank you, on behalf of the entire kingdom, on behalf of my entire 65 million subjects, for saving our lives from the Evil Twin-headed Dragon Dodura, that had been tormenting our kingdom for so long, even our beautiful capital city of Astral was losing her vibrance, she is now recovering.',
#  'And it\'s all because of you."',
#  'Everybody looked at Tal.',
#  'He was the center of undivided attention.',
#  '"I know words are not enough.',
#  'So I wanted to give you this.',
#  "The rarest and the most delicious fruit you'll find in the entire world.",
#  "Fruit that doesn't rot in 100 years, that cures incurable diseases, also is unbelievably delicious, only those who have tasted can confirm.",
#  'Only a handful of them, that our former Great General Snorz laid down his life to secure from the treacherous Southern islands, and this is the last one remaining."',
#  'Everybody listened to the king with awe.',
#  'The king concluded, ordering the Head Cook to remove the cover.',
#  '"Tal, I want you to have it.',
#  'Behold, the rarest of the rare, The Mystic Pomegranite!"',
#  'Everybody looked with complete attention as the Head Cook removed the cover.',
#  'Then they were little bit startled.',
#  'They were confused!',
#  'Really?',
#  "The king's face looked lifeless, stoic.",
#  'Head Cook is silent.',
#  'They were all looking at the plate.',
#  "It's empty!",
#  'People at the back started gossiping.',
#  '"What happened!?',
#  'What happened to the fruit?"',
#  '"Somebody stole the fruit!',
#  'Really?"',
#  '"Mystic Pomegranite?',
#  'A miracle fruit!?',
#  'Never heard of it."',
#  '"The General laid down his life for a stupid fruit?',
#  'I thought it was…"\n"I\'m sure it\'s the Head Cook.',
#  'Look at his face.',
#  'The fruit is so great, who wouldn\'t…"\n"Feel so bad for The Hero.',
#  'The king is…"\nThe king was looking at the plate with lifeless eyes.',
#  'Now he looked at the crowd.',
#  'He looked angry.',
#  'The crowd became silent in an instant.',
#  "The king moved his face towards the Head Cook, he's standing silent with eyes closed.",
#  'The Hero observed the whole situation.',
#  'He felt awkward.',
#  '"Head Cook", the king called in a low deep voice.',
#  '"At your service, your Highness!"',
#  '"Please explain."',
#  '"Yes!',
#  'Welcome Tal, my Hero, to our beautiful kingdom of Purplewoods, south of the beautiful Purplewoods Forest, ruled by his Majesty, the mighty king Thoros.',
#  'In the name of his highness let me introduce you our kingdom\'s finest cuisine."',
#  'The king observed the situation, but stayed silent.',
#  'The Head Cook took a mug of wine.',
#  '"The Purple Wine, made from the juice of the finest quality purple grapes, that you may have already started with, all made under my direct oversight.',
#  "Then comes Fire Chicken, don't confuse this with regular chickens, they're the finest breed of chickens imported from the Western kingdoms, I have made it personally with my hands.",
#  "Once you eat, you'll keep coming back.",
#  'Then…"\n"Silence", the king shouted at the Head Cook.',
#  'Everybody in the hall had their faces pale in fear.',
#  'The Hero was observing the whole situation, trying to be calm, but feeling awkward.',
#  '"Where is the Mystic Pomegranite!?"',
#  'The Head Cook stayed silent.',
#  '"It was your responsibility to keep it safe, and bring it for Tal.',
#  'Where is it?"',
#  "The king's eyes turned blood-red.",
#  'The crowd wondered about the situation, but scared to gossip about anything.',
#  '"Your Highness", the head cook said.',
#  'The king stared at him.',
#  '"I\'m deeply saddened to see that the Wonder Fruit has gone missing.',
#  'At your direction I will quickly direct the cooks to search for it", the head cook said in a calm and quiet tone.',
#  'It was pretty apparent that he was trying to mock the king.',
#  'But why!?',
#  'Everybody wondered.',
#  '"What nonsense!?',
#  "It's not only the cooks, I'll also direct the soldiers to search for it.",
#  'Guards, search every nook and corner of the Castle and find the Miracle Fruit, the Mystic Pomegranite for our hero ASAP", the king directed.',
#  'His voice echoed in the walls of the giant hall.',
#  'The cooks and the guards immediately started moving around in search of the fruit.',
#  'They were searching everywhere possible, in the kitchen, armory, bathhouse, below mats, behind furnitures and other decorations, some were also asking and searching people in the Castle.',
#  'On the other hand the people who came to the Castle were all in a state of shock and panic.',
#  "Everybody started talking, nobody's sure what's going on.",
#  '"Better I should also assist the young cooks in the Great Search", the head cook said as he wanted to go and search.',
#  '"Shut Up Head Cook!',
#  'You\'re not going anywhere, unless I wish so", the king noticed the Head Cook\'s intent and stopped him immediately.',
#  '"At your service your Highness", the Cook said.',
#  'He was surprisingly calm in such a tense situation.']

# %%
words = word_tokenize(corpus)

words
# Out:
# ['The',
#  'Hero',
#  ',',
#  'the',
#  'King',
#  ',',
#  'and',
#  'the',
#  'Cook',
#  "''",
#  'Tal',
#  ',',
#  'I',
#  "'m",
#  'so',
#  'happy',
#  'to',
#  'see',
#  'you',
#  'here',
#  '.',
#  'I',
#  'can',
#  'not',
#  'thank',
#  'you',
#  'enough',
#  'for',
#  'saving',
#  'my',
#  'kingdom',
#  ',',
#  'we',
#  "'re",
#  'all',
#  'safe',
#  'because',
#  'of',
#  'you',
#  '.',
#  'You',
#  "'re",
#  'the',
#  'true',
#  'Hero',
#  '!',
#  "''",
#  '``',
#  'Yeah',
#  'it',
#  'was',
#  'a',
#  'predicament',
#  'for',
#  'sure',
#  '.',
#  'Somebody',
#  'had',
#  'to',
#  'do',
#  'it',
#  '.',
#  'I',
#  'did',
#  'it',
#  '.',
#  'Haha',
#  "''",
#  "''",
#  'You',
#  "'re",
#  'as',
#  'cheerful',
#  'as',
#  'ever',
#  '.',
#  'Tal',
#  ',',
#  'I',
#  'do',
#  "n't",
#  'think',
#  'it',
#  "'s",
#  'enough',
#  ',',
#  'but',
#  'in',
#  'your',
#  'honor',
#  'I',
#  'have',
#  'decided',
#  'to',
#  'throw',
#  'the',
#  'biggest',
#  'party',
#  'you',
#  "'ve",
#  'ever',
#  'seen',
#  '.',
#  'Eat',
#  ',',
#  'drink',
#  'and',
#  'party',
#  'as',
#  'much',
#  'as',
#  'you',
#  'want',
#  ',',
#  'do',
#  "n't",
#  'hesitate',
#  '!',
#  "''",
#  '``',
#  'Cheers',
#  ',',
#  'for',
#  'the',
#  'kingdom',
#  ',',
#  'and',
#  'for',
#  'the',
#  'king',
#  '!',
#  "''",
#  'The',
#  'Hero',
#  'and',
#  'the',
#  'King',
#  'were',
#  'seated',
#  'side',
#  'by',
#  'side',
#  'at',
#  'the',
#  'center',
#  'of',
#  'a',
#  'giant',
#  'hall',
#  ',',
#  'eating',
#  'and',
#  'drinking',
#  'from',
#  'a',
#  'hundred',
#  'dishes',
#  'exhibited',
#  'right',
#  'in',
#  'front',
#  'of',
#  'them',
#  'in',
#  'a',
#  'giant',
#  'table',
#  '.',
#  'A',
#  'lot',
#  'of',
#  'very',
#  'very',
#  'important',
#  'people',
#  '(',
#  'VVIPs',
#  ')',
#  'were',
#  'surrounding',
#  'them',
#  ',',
#  'ministers',
#  ',',
#  'bureaucrats',
#  ',',
#  'priests',
#  ',',
#  'scholars',
#  ',',
#  'merchants',
#  ',',
#  'all',
#  'trying',
#  'to',
#  'get',
#  'a',
#  'glimpse',
#  'of',
#  'the',
#  'Hero',
#  ',',
#  'possibly',
#  'talk',
#  'to',
#  'him',
#  '.',
#  'Everybody',
#  'was',
#  'in',
#  'total',
#  'awe',
#  ',',
#  'some',
#  'even',
#  'offered',
#  'the',
#  'hand',
#  'of',
#  'their',
#  'daughter',
#  ',',
#  'the',
#  'Hero',
#  'was',
#  'cheerful',
#  'but',
#  'unbothered',
#  '.',
#  'Outside',
#  'even',
#  'the',
#  'commoners',
#  'were',
#  'in',
#  'a',
#  'festive',
#  'mood',
#  '.',
#  'They',
#  'were',
#  'all',
#  'singing',
#  'praises',
#  'of',
#  'the',
#  'hero',
#  ',',
#  'and',
#  'dancing',
#  '.',
#  'Many',
#  'offered',
#  'big',
#  'discounts',
#  'in',
#  'their',
#  'shops',
#  ',',
#  'while',
#  'some',
#  'hiked',
#  'prices',
#  'and',
#  'bagged',
#  'profits',
#  ',',
#  'all',
#  'in',
#  'the',
#  'Hero',
#  "'s",
#  'honor',
#  '.',
#  '``',
#  'Tal',
#  ',',
#  'what',
#  'do',
#  'you',
#  'think',
#  '?',
#  'I',
#  'bet',
#  ',',
#  'you',
#  "'ve",
#  'never',
#  'been',
#  'to',
#  'a',
#  'party',
#  'as',
#  'grand',
#  'as',
#  'this',
#  'one',
#  'before',
#  '!',
#  "''",
#  '``',
#  'You',
#  'bet',
#  '!',
#  'The',
#  'others',
#  'does',
#  "n't",
#  'even',
#  'look',
#  'like',
#  'parties',
#  'now',
#  '.',
#  "''",
#  '``',
#  'The',
#  'biggest',
#  'surprise',
#  'is',
#  'not',
#  'yet',
#  'here',
#  '.',
#  'Everything',
#  'you',
#  'see',
#  'now',
#  'pales',
#  'in',
#  'comparison',
#  '.',
#  "''",
#  '``',
#  'Oh',
#  'still',
#  'something',
#  'bigger',
#  'is',
#  'left',
#  '?',
#  "''",
#  '``',
#  'Much',
#  'much',
#  'bigger',
#  ',',
#  'something',
#  'you',
#  'have',
#  'never',
#  'imagined',
#  '!',
#  "''",
#  '``',
#  'Oh',
#  'what',
#  'could',
#  'that',
#  'be',
#  '?',
#  'I',
#  'know',
#  ',',
#  'I',
#  'know',
#  ',',
#  'the',
#  'hand',
#  'of',
#  'the',
#  'princess',
#  '!',
#  'Oh',
#  'come',
#  'on',
#  ',',
#  'I',
#  'can',
#  'not',
#  'settle',
#  'down',
#  'right',
#  'now',
#  ',',
#  'I',
#  'love',
#  'being',
#  'a',
#  'hero',
#  ',',
#  'but',
#  'since',
#  'you',
#  'insist',
#  ',',
#  'I',
#  'will',
#  'think',
#  'on…',
#  "''",
#  "''",
#  'That',
#  "'s",
#  'right',
#  ',',
#  'that',
#  "'s",
#  'right',
#  ',',
#  'now',
#  'is',
#  'not',
#  'really',
#  'the',
#  'time',
#  'for',
#  'you',
#  'to',
#  'settle',
#  ',',
#  'I',
#  'have',
#  'never',
#  'seen',
#  'a',
#  'fine',
#  'warrior',
#  'like',
#  'you',
#  'before',
#  ',',
#  'you',
#  'have',
#  'plenty',
#  'of',
#  'time',
#  'ahead',
#  ',',
#  'or',
#  'do',
#  'you',
#  'want',
#  'a',
#  'big',
#  'fat',
#  'tummy',
#  'like',
#  'mine',
#  '?',
#  "''",
#  '``',
#  'Haha',
#  'and',
#  'then',
#  'I',
#  'have',
#  'to',
#  'hire',
#  'another',
#  'Hero',
#  'to',
#  'save',
#  'my',
#  'kingdom',
#  ',',
#  'I',
#  'can',
#  'never',
#  'let',
#  'that',
#  'happen',
#  '!',
#  'At',
#  'least',
#  'not',
#  'before',
#  'I',
#  'tame',
#  'a',
#  'Dragon',
#  'from',
#  'the',
#  'village',
#  'of',
#  'Dragon',
#  'Tamers',
#  '.',
#  "''",
#  '``',
#  'Maybe',
#  'I',
#  'can',
#  'fund',
#  'your',
#  'adventure',
#  'over',
#  'there',
#  ',',
#  'only',
#  'bring',
#  'me',
#  '3',
#  'Fire',
#  'Dragons',
#  'for',
#  'my',
#  'kingdom',
#  "'s",
#  'protection',
#  '.',
#  "''",
#  '``',
#  'Sure',
#  'sure',
#  '.',
#  'Why',
#  'not',
#  '?',
#  'Anyway',
#  ',',
#  'I',
#  "'m",
#  'still',
#  'curious',
#  ',',
#  'what',
#  'is',
#  'the',
#  'big',
#  'bang',
#  'thing',
#  ',',
#  'that',
#  "'s",
#  'coming',
#  'next',
#  '?',
#  "''",
#  '``',
#  'Here',
#  'it',
#  'is',
#  "''",
#  ',',
#  'the',
#  'king',
#  'directed',
#  'Tal',
#  '.',
#  'The',
#  'Head',
#  'Cook',
#  'arrived',
#  ',',
#  'along',
#  'with',
#  'him',
#  'came',
#  'something',
#  'grand',
#  '.',
#  'Everybody',
#  'wondered',
#  ',',
#  'a',
#  'secret',
#  'dish',
#  '?',
#  'But',
#  'it',
#  'is',
#  'covered',
#  '.',
#  'Everybody',
#  'is',
#  'curious',
#  '.',
#  'What',
#  'could',
#  'that',
#  'be',
#  '!',
#  '?',
#  '``',
#  'Tal',
#  ',',
#  'once',
#  'again',
#  'I',
#  "'d",
#  'like',
#  'to',
#  'take',
#  'this',
#  'opportunity',
#  'to',
#  'thank',
#  'you',
#  ',',
#  'on',
#  'behalf',
#  'of',
#  'the',
#  'entire',
#  'kingdom',
#  ',',
#  'on',
#  'behalf',
#  'of',
#  'my',
#  'entire',
#  '65',
#  'million',
#  'subjects',
#  ',',
#  'for',
#  'saving',
#  'our',
#  'lives',
#  'from',
#  'the',
#  'Evil',
#  'Twin-headed',
#  'Dragon',
#  'Dodura',
#  ',',
#  'that',
#  'had',
#  'been',
#  'tormenting',
#  'our',
#  'kingdom',
#  'for',
#  'so',
#  'long',
#  ',',
#  'even',
#  'our',
#  'beautiful',
#  'capital',
#  'city',
#  'of',
#  'Astral',
#  'was',
#  'losing',
#  'her',
#  'vibrance',
#  ',',
#  'she',
#  'is',
#  'now',
#  'recovering',
#  '.',
#  'And',
#  'it',
#  "'s",
#  'all',
#  'because',
#  'of',
#  'you',
#  '.',
#  "''",
#  'Everybody',
#  'looked',
#  'at',
#  'Tal',
#  '.',
#  'He',
#  'was',
#  'the',
#  'center',
#  'of',
#  'undivided',
#  'attention',
#  '.',
#  '``',
#  'I',
#  'know',
#  'words',
#  'are',
#  'not',
#  'enough',
#  '.',
#  'So',
#  'I',
#  'wanted',
#  'to',
#  'give',
#  'you',
#  'this',
#  '.',
#  'The',
#  'rarest',
#  'and',
#  'the',
#  'most',
#  'delicious',
#  'fruit',
#  'you',
#  "'ll",
#  'find',
#  'in',
#  'the',
#  'entire',
#  'world',
#  '.',
#  'Fruit',
#  'that',
#  'does',
#  "n't",
#  'rot',
#  'in',
#  '100',
#  'years',
#  ',',
#  'that',
#  'cures',
#  'incurable',
#  'diseases',
#  ',',
#  'also',
#  'is',
#  'unbelievably',
#  'delicious',
#  ',',
#  'only',
#  'those',
#  'who',
#  'have',
#  'tasted',
#  'can',
#  'confirm',
#  '.',
#  'Only',
#  'a',
#  'handful',
#  'of',
#  'them',
#  ',',
#  'that',
#  'our',
#  'former',
#  'Great',
#  'General',
#  'Snorz',
#  'laid',
#  'down',
#  'his',
#  'life',
#  'to',
#  'secure',
#  'from',
#  'the',
#  'treacherous',
#  'Southern',
#  'islands',
#  ',',
#  'and',
#  'this',
#  'is',
#  'the',
#  'last',
#  'one',
#  'remaining',
#  '.',
#  "''",
#  'Everybody',
#  'listened',
#  'to',
#  'the',
#  'king',
#  'with',
#  'awe',
#  '.',
#  'The',
#  'king',
#  'concluded',
#  ',',
#  'ordering',
#  'the',
#  'Head',
#  'Cook',
#  'to',
#  'remove',
#  'the',
#  'cover',
#  '.',
#  '``',
#  'Tal',
#  ',',
#  'I',
#  'want',
#  'you',
#  'to',
#  'have',
#  'it',
#  '.',
#  'Behold',
#  ',',
#  'the',
#  'rarest',
#  'of',
#  'the',
#  'rare',
#  ',',
#  'The',
#  'Mystic',
#  'Pomegranite',
#  '!',
#  "''",
#  'Everybody',
#  'looked',
#  'with',
#  'complete',
#  'attention',
#  'as',
#  'the',
#  'Head',
#  'Cook',
#  'removed',
#  'the',
#  'cover',
#  '.',
#  'Then',
#  'they',
#  'were',
#  'little',
#  'bit',
#  'startled',
#  '.',
#  'They',
#  'were',
#  'confused',
#  '!',
#  'Really',
#  '?',
#  'The',
#  'king',
#  "'s",
#  'face',
#  'looked',
#  'lifeless',
#  ',',
#  'stoic',
#  '.',
#  'Head',
#  'Cook',
#  'is',
#  'silent',
#  '.',
#  'They',
#  'were',
#  'all',
#  'looking',
#  'at',
#  'the',
#  'plate',
#  '.',
#  'It',
#  "'s",
#  'empty',
#  '!',
#  'People',
#  'at',
#  'the',
#  'back',
#  'started',
#  'gossiping',
#  '.',
#  '``',
#  'What',
#  'happened',
#  '!',
#  '?',
#  'What',
#  'happened',
#  'to',
#  'the',
#  'fruit',
#  '?',
#  "''",
#  '``',
#  'Somebody',
#  'stole',
#  'the',
#  'fruit',
#  '!',
#  'Really',
#  '?',
#  "''",
#  '``',
#  'Mystic',
#  'Pomegranite',
#  '?',
#  'A',
#  'miracle',
#  'fruit',
#  '!',
#  '?',
#  'Never',
#  'heard',
#  'of',
#  'it',
#  '.',
#  "''",
#  '``',
#  'The',
#  'General',
#  'laid',
#  'down',
#  'his',
#  'life',
#  'for',
#  'a',
#  'stupid',
#  'fruit',
#  '?',
#  'I',
#  'thought',
#  'it',
#  'was…',
#  "''",
#  "''",
#  'I',
#  "'m",
#  'sure',
#  'it',
#  "'s",
#  'the',
#  'Head',
#  'Cook',
#  '.',
#  'Look',
#  'at',
#  'his',
#  'face',
#  '.',
#  'The',
#  'fruit',
#  'is',
#  'so',
#  'great',
#  ',',
#  'who',
#  "wouldn't…",
#  "''",
#  "''",
#  'Feel',
#  'so',
#  'bad',
#  'for',
#  'The',
#  'Hero',
#  '.',
#  'The',
#  'king',
#  'is…',
#  "''",
#  'The',
#  'king',
#  'was',
#  'looking',
#  'at',
#  'the',
#  'plate',
#  'with',
#  'lifeless',
#  'eyes',
#  '.',
#  'Now',
#  'he',
#  'looked',
#  'at',
#  'the',
#  'crowd',
#  '.',
#  'He',
#  'looked',
#  'angry',
#  '.',
#  'The',
#  'crowd',
#  'became',
#  'silent',
#  'in',
#  'an',
#  'instant',
#  '.',
#  'The',
#  'king',
#  'moved',
#  'his',
#  'face',
#  'towards',
#  'the',
#  'Head',
#  'Cook',
#  ',',
#  'he',
#  ...]

# %%
sentences_punct = wordpunct_tokenize(corpus)

sentences_punct
# Out:
# ['The',
#  'Hero',
#  ',',
#  'the',
#  'King',
#  ',',
#  'and',
#  'the',
#  'Cook',
#  '"',
#  'Tal',
#  ',',
#  'I',
#  "'",
#  'm',
#  'so',
#  'happy',
#  'to',
#  'see',
#  'you',
#  'here',
#  '.',
#  'I',
#  'cannot',
#  'thank',
#  'you',
#  'enough',
#  'for',
#  'saving',
#  'my',
#  'kingdom',
#  ',',
#  'we',
#  "'",
#  're',
#  'all',
#  'safe',
#  'because',
#  'of',
#  'you',
#  '.',
#  'You',
#  "'",
#  're',
#  'the',
#  'true',
#  'Hero',
#  '!"',
#  '"',
#  'Yeah',
#  'it',
#  'was',
#  'a',
#  'predicament',
#  'for',
#  'sure',
#  '.',
#  'Somebody',
#  'had',
#  'to',
#  'do',
#  'it',
#  '.',
#  'I',
#  'did',
#  'it',
#  '.',
#  'Haha',
#  '"',
#  '"',
#  'You',
#  "'",
#  're',
#  'as',
#  'cheerful',
#  'as',
#  'ever',
#  '.',
#  'Tal',
#  ',',
#  'I',
#  'don',
#  "'",
#  't',
#  'think',
#  'it',
#  "'",
#  's',
#  'enough',
#  ',',
#  'but',
#  'in',
#  'your',
#  'honor',
#  'I',
#  'have',
#  'decided',
#  'to',
#  'throw',
#  'the',
#  'biggest',
#  'party',
#  'you',
#  "'",
#  've',
#  'ever',
#  'seen',
#  '.',
#  'Eat',
#  ',',
#  'drink',
#  'and',
#  'party',
#  'as',
#  'much',
#  'as',
#  'you',
#  'want',
#  ',',
#  'don',
#  "'",
#  't',
#  'hesitate',
#  '!"',
#  '"',
#  'Cheers',
#  ',',
#  'for',
#  'the',
#  'kingdom',
#  ',',
#  'and',
#  'for',
#  'the',
#  'king',
#  '!"',
#  'The',
#  'Hero',
#  'and',
#  'the',
#  'King',
#  'were',
#  'seated',
#  'side',
#  'by',
#  'side',
#  'at',
#  'the',
#  'center',
#  'of',
#  'a',
#  'giant',
#  'hall',
#  ',',
#  'eating',
#  'and',
#  'drinking',
#  'from',
#  'a',
#  'hundred',
#  'dishes',
#  'exhibited',
#  'right',
#  'in',
#  'front',
#  'of',
#  'them',
#  'in',
#  'a',
#  'giant',
#  'table',
#  '.',
#  'A',
#  'lot',
#  'of',
#  'very',
#  'very',
#  'important',
#  'people',
#  '(',
#  'VVIPs',
#  ')',
#  'were',
#  'surrounding',
#  'them',
#  ',',
#  'ministers',
#  ',',
#  'bureaucrats',
#  ',',
#  'priests',
#  ',',
#  'scholars',
#  ',',
#  'merchants',
#  ',',
#  'all',
#  'trying',
#  'to',
#  'get',
#  'a',
#  'glimpse',
#  'of',
#  'the',
#  'Hero',
#  ',',
#  'possibly',
#  'talk',
#  'to',
#  'him',
#  '.',
#  'Everybody',
#  'was',
#  'in',
#  'total',
#  'awe',
#  ',',
#  'some',
#  'even',
#  'offered',
#  'the',
#  'hand',
#  'of',
#  'their',
#  'daughter',
#  ',',
#  'the',
#  'Hero',
#  'was',
#  'cheerful',
#  'but',
#  'unbothered',
#  '.',
#  'Outside',
#  'even',
#  'the',
#  'commoners',
#  'were',
#  'in',
#  'a',
#  'festive',
#  'mood',
#  '.',
#  'They',
#  'were',
#  'all',
#  'singing',
#  'praises',
#  'of',
#  'the',
#  'hero',
#  ',',
#  'and',
#  'dancing',
#  '.',
#  'Many',
#  'offered',
#  'big',
#  'discounts',
#  'in',
#  'their',
#  'shops',
#  ',',
#  'while',
#  'some',
#  'hiked',
#  'prices',
#  'and',
#  'bagged',
#  'profits',
#  ',',
#  'all',
#  'in',
#  'the',
#  'Hero',
#  "'",
#  's',
#  'honor',
#  '.',
#  '"',
#  'Tal',
#  ',',
#  'what',
#  'do',
#  'you',
#  'think',
#  '?',
#  'I',
#  'bet',
#  ',',
#  'you',
#  "'",
#  've',
#  'never',
#  'been',
#  'to',
#  'a',
#  'party',
#  'as',
#  'grand',
#  'as',
#  'this',
#  'one',
#  'before',
#  '!"',
#  '"',
#  'You',
#  'bet',
#  '!',
#  'The',
#  'others',
#  'doesn',
#  "'",
#  't',
#  'even',
#  'look',
#  'like',
#  'parties',
#  'now',
#  '."',
#  '"',
#  'The',
#  'biggest',
#  'surprise',
#  'is',
#  'not',
#  'yet',
#  'here',
#  '.',
#  'Everything',
#  'you',
#  'see',
#  'now',
#  'pales',
#  'in',
#  'comparison',
#  '."',
#  '"',
#  'Oh',
#  'still',
#  'something',
#  'bigger',
#  'is',
#  'left',
#  '?"',
#  '"',
#  'Much',
#  'much',
#  'bigger',
#  ',',
#  'something',
#  'you',
#  'have',
#  'never',
#  'imagined',
#  '!"',
#  '"',
#  'Oh',
#  'what',
#  'could',
#  'that',
#  'be',
#  '?',
#  'I',
#  'know',
#  ',',
#  'I',
#  'know',
#  ',',
#  'the',
#  'hand',
#  'of',
#  'the',
#  'princess',
#  '!',
#  'Oh',
#  'come',
#  'on',
#  ',',
#  'I',
#  'cannot',
#  'settle',
#  'down',
#  'right',
#  'now',
#  ',',
#  'I',
#  'love',
#  'being',
#  'a',
#  'hero',
#  ',',
#  'but',
#  'since',
#  'you',
#  'insist',
#  ',',
#  'I',
#  'will',
#  'think',
#  'on',
#  '…"',
#  '"',
#  'That',
#  "'",
#  's',
#  'right',
#  ',',
#  'that',
#  "'",
#  's',
#  'right',
#  ',',
#  'now',
#  'is',
#  'not',
#  'really',
#  'the',
#  'time',
#  'for',
#  'you',
#  'to',
#  'settle',
#  ',',
#  'I',
#  'have',
#  'never',
#  'seen',
#  'a',
#  'fine',
#  'warrior',
#  'like',
#  'you',
#  'before',
#  ',',
#  'you',
#  'have',
#  'plenty',
#  'of',
#  'time',
#  'ahead',
#  ',',
#  'or',
#  'do',
#  'you',
#  'want',
#  'a',
#  'big',
#  'fat',
#  'tummy',
#  'like',
#  'mine',
#  '?"',
#  '"',
#  'Haha',
#  'and',
#  'then',
#  'I',
#  'have',
#  'to',
#  'hire',
#  'another',
#  'Hero',
#  'to',
#  'save',
#  'my',
#  'kingdom',
#  ',',
#  'I',
#  'can',
#  'never',
#  'let',
#  'that',
#  'happen',
#  '!',
#  'At',
#  'least',
#  'not',
#  'before',
#  'I',
#  'tame',
#  'a',
#  'Dragon',
#  'from',
#  'the',
#  'village',
#  'of',
#  'Dragon',
#  'Tamers',
#  '."',
#  '"',
#  'Maybe',
#  'I',
#  'can',
#  'fund',
#  'your',
#  'adventure',
#  'over',
#  'there',
#  ',',
#  'only',
#  'bring',
#  'me',
#  '3',
#  'Fire',
#  'Dragons',
#  'for',
#  'my',
#  'kingdom',
#  "'",
#  's',
#  'protection',
#  '."',
#  '"',
#  'Sure',
#  'sure',
#  '.',
#  'Why',
#  'not',
#  '?',
#  'Anyway',
#  ',',
#  'I',
#  "'",
#  'm',
#  'still',
#  'curious',
#  ',',
#  'what',
#  'is',
#  'the',
#  'big',
#  'bang',
#  'thing',
#  ',',
#  'that',
#  "'",
#  's',
#  'coming',
#  'next',
#  '?"',
#  '"',
#  'Here',
#  'it',
#  'is',
#  '",',
#  'the',
#  'king',
#  'directed',
#  'Tal',
#  '.',
#  'The',
#  'Head',
#  'Cook',
#  'arrived',
#  ',',
#  'along',
#  'with',
#  'him',
#  'came',
#  'something',
#  'grand',
#  '.',
#  'Everybody',
#  'wondered',
#  ',',
#  'a',
#  'secret',
#  'dish',
#  '?',
#  'But',
#  'it',
#  'is',
#  'covered',
#  '.',
#  'Everybody',
#  'is',
#  'curious',
#  '.',
#  'What',
#  'could',
#  'that',
#  'be',
#  '!?',
#  '"',
#  'Tal',
#  ',',
#  'once',
#  'again',
#  'I',
#  "'",
#  'd',
#  'like',
#  'to',
#  'take',
#  'this',
#  'opportunity',
#  'to',
#  'thank',
#  'you',
#  ',',
#  'on',
#  'behalf',
#  'of',
#  'the',
#  'entire',
#  'kingdom',
#  ',',
#  'on',
#  'behalf',
#  'of',
#  'my',
#  'entire',
#  '65',
#  'million',
#  'subjects',
#  ',',
#  'for',
#  'saving',
#  'our',
#  'lives',
#  'from',
#  'the',
#  'Evil',
#  'Twin',
#  '-',
#  'headed',
#  'Dragon',
#  'Dodura',
#  ',',
#  'that',
#  'had',
#  'been',
#  'tormenting',
#  'our',
#  'kingdom',
#  'for',
#  'so',
#  'long',
#  ',',
#  'even',
#  'our',
#  'beautiful',
#  'capital',
#  'city',
#  'of',
#  'Astral',
#  'was',
#  'losing',
#  'her',
#  'vibrance',
#  ',',
#  'she',
#  'is',
#  'now',
#  'recovering',
#  '.',
#  'And',
#  'it',
#  "'",
#  's',
#  'all',
#  'because',
#  'of',
#  'you',
#  '."',
#  'Everybody',
#  'looked',
#  'at',
#  'Tal',
#  '.',
#  'He',
#  'was',
#  'the',
#  'center',
#  'of',
#  'undivided',
#  'attention',
#  '.',
#  '"',
#  'I',
#  'know',
#  'words',
#  'are',
#  'not',
#  'enough',
#  '.',
#  'So',
#  'I',
#  'wanted',
#  'to',
#  'give',
#  'you',
#  'this',
#  '.',
#  'The',
#  'rarest',
#  'and',
#  'the',
#  'most',
#  'delicious',
#  'fruit',
#  'you',
#  "'",
#  'll',
#  'find',
#  'in',
#  'the',
#  'entire',
#  'world',
#  '.',
#  'Fruit',
#  'that',
#  'doesn',
#  "'",
#  't',
#  'rot',
#  'in',
#  '100',
#  'years',
#  ',',
#  'that',
#  'cures',
#  'incurable',
#  'diseases',
#  ',',
#  'also',
#  'is',
#  'unbelievably',
#  'delicious',
#  ',',
#  'only',
#  'those',
#  'who',
#  'have',
#  'tasted',
#  'can',
#  'confirm',
#  '.',
#  'Only',
#  'a',
#  'handful',
#  'of',
#  'them',
#  ',',
#  'that',
#  'our',
#  'former',
#  'Great',
#  'General',
#  'Snorz',
#  'laid',
#  'down',
#  'his',
#  'life',
#  'to',
#  'secure',
#  'from',
#  'the',
#  'treacherous',
#  'Southern',
#  'islands',
#  ',',
#  'and',
#  'this',
#  'is',
#  'the',
#  'last',
#  'one',
#  'remaining',
#  '."',
#  'Everybody',
#  'listened',
#  'to',
#  'the',
#  'king',
#  'with',
#  'awe',
#  '.',
#  'The',
#  'king',
#  'concluded',
#  ',',
#  'ordering',
#  'the',
#  'Head',
#  'Cook',
#  'to',
#  'remove',
#  'the',
#  'cover',
#  '.',
#  '"',
#  'Tal',
#  ',',
#  'I',
#  'want',
#  'you',
#  'to',
#  'have',
#  'it',
#  '.',
#  'Behold',
#  ',',
#  'the',
#  'rarest',
#  'of',
#  'the',
#  'rare',
#  ',',
#  'The',
#  'Mystic',
#  'Pomegranite',
#  '!"',
#  'Everybody',
#  'looked',
#  'with',
#  'complete',
#  'attention',
#  'as',
#  'the',
#  'Head',
#  'Cook',
#  'removed',
#  'the',
#  'cover',
#  '.',
#  'Then',
#  'they',
#  'were',
#  'little',
#  'bit',
#  'startled',
#  '.',
#  'They',
#  'were',
#  'confused',
#  '!',
#  'Really',
#  '?',
#  'The',
#  'king',
#  "'",
#  's',
#  'face',
#  'looked',
#  'lifeless',
#  ',',
#  'stoic',
#  '.',
#  'Head',
#  'Cook',
#  'is',
#  'silent',
#  '.',
#  'They',
#  'were',
#  'all',
#  'looking',
#  'at',
#  'the',
#  'plate',
#  '.',
#  'It',
#  "'",
#  's',
#  'empty',
#  '!',
#  'People',
#  'at',
#  'the',
#  'back',
#  'started',
#  'gossiping',
#  '.',
#  '"',
#  'What',
#  'happened',
#  '!?',
#  'What',
#  'happened',
#  'to',
#  'the',
#  'fruit',
#  '?"',
#  '"',
#  'Somebody',
#  'stole',
#  'the',
#  'fruit',
#  '!',
#  'Really',
#  '?"',
#  '"',
#  'Mystic',
#  'Pomegranite',
#  '?',
#  'A',
#  'miracle',
#  'fruit',
#  '!?',
#  'Never',
#  'heard',
#  'of',
#  'it',
#  '."',
#  '"',
#  'The',
#  'General',
#  'laid',
#  'down',
#  'his',
#  'life',
#  'for',
#  'a',
#  'stupid',
#  'fruit',
#  '?',
#  'I',
#  'thought',
#  'it',
#  'was',
#  '…"',
#  '"',
#  'I',
#  "'",
#  'm',
#  'sure',
#  'it',
#  "'",
#  's',
#  'the',
#  'Head',
#  'Cook',
#  '.',
#  'Look',
#  'at',
#  'his',
#  'face',
#  '.',
#  'The',
#  'fruit',
#  'is',
#  'so',
#  'great',
#  ',',
#  'who',
#  'wouldn',
#  "'",
#  't',
#  '…"',
#  '"',
#  'Feel',
#  'so',
#  'bad',
#  'for',
#  'The',
#  'Hero',
#  '.',
#  'The',
#  'king',
#  'is',
#  '…"',
#  'The',
#  'king',
#  'was',
#  'looking',
#  'at',
#  'the',
#  'plate',
#  'with',
#  'lifeless',
#  'eyes',
#  '.',
#  'Now',
#  'he',
#  'looked',
#  'at',
#  'the',
#  'crowd',
#  '.',
#  'He',
#  'looked',
#  'angry',
#  '.',
#  'The',
#  'crowd',
#  'became',
#  'silent',
#  'in',
#  'an',
#  'instant',
#  '.',
#  'The',
#  'king',
#  'moved',
#  'his',
#  'face',
#  'towards',
#  'the',
#  ...]

# %%
for sentence in sentences:
    word = word_tokenize(sentence)
    print(word)
# Out:
# ['The', 'Hero', ',', 'the', 'King', ',', 'and', 'the', 'Cook', "''", 'Tal', ',', 'I', "'m", 'so', 'happy', 'to', 'see', 'you', 'here', '.']
# ['I', 'can', 'not', 'thank', 'you', 'enough', 'for', 'saving', 'my', 'kingdom', ',', 'we', "'re", 'all', 'safe', 'because', 'of', 'you', '.']
# ['You', "'re", 'the', 'true', 'Hero', '!', "''"]
# ['``', 'Yeah', 'it', 'was', 'a', 'predicament', 'for', 'sure', '.']
# ['Somebody', 'had', 'to', 'do', 'it', '.']
# ['I', 'did', 'it', '.']
# ['Haha', "''", "''", 'You', "'re", 'as', 'cheerful', 'as', 'ever', '.']
# ['Tal', ',', 'I', 'do', "n't", 'think', 'it', "'s", 'enough', ',', 'but', 'in', 'your', 'honor', 'I', 'have', 'decided', 'to', 'throw', 'the', 'biggest', 'party', 'you', "'ve", 'ever', 'seen', '.']
# ['Eat', ',', 'drink', 'and', 'party', 'as', 'much', 'as', 'you', 'want', ',', 'do', "n't", 'hesitate', '!', "''"]
# ['``', 'Cheers', ',', 'for', 'the', 'kingdom', ',', 'and', 'for', 'the', 'king', '!', "''"]
# ['The', 'Hero', 'and', 'the', 'King', 'were', 'seated', 'side', 'by', 'side', 'at', 'the', 'center', 'of', 'a', 'giant', 'hall', ',', 'eating', 'and', 'drinking', 'from', 'a', 'hundred', 'dishes', 'exhibited', 'right', 'in', 'front', 'of', 'them', 'in', 'a', 'giant', 'table', '.']
# ['A', 'lot', 'of', 'very', 'very', 'important', 'people', '(', 'VVIPs', ')', 'were', 'surrounding', 'them', ',', 'ministers', ',', 'bureaucrats', ',', 'priests', ',', 'scholars', ',', 'merchants', ',', 'all', 'trying', 'to', 'get', 'a', 'glimpse', 'of', 'the', 'Hero', ',', 'possibly', 'talk', 'to', 'him', '.']
# ['Everybody', 'was', 'in', 'total', 'awe', ',', 'some', 'even', 'offered', 'the', 'hand', 'of', 'their', 'daughter', ',', 'the', 'Hero', 'was', 'cheerful', 'but', 'unbothered', '.']
# ['Outside', 'even', 'the', 'commoners', 'were', 'in', 'a', 'festive', 'mood', '.']
# ['They', 'were', 'all', 'singing', 'praises', 'of', 'the', 'hero', ',', 'and', 'dancing', '.']
# ['Many', 'offered', 'big', 'discounts', 'in', 'their', 'shops', ',', 'while', 'some', 'hiked', 'prices', 'and', 'bagged', 'profits', ',', 'all', 'in', 'the', 'Hero', "'s", 'honor', '.']
# ['``', 'Tal', ',', 'what', 'do', 'you', 'think', '?']
# ['I', 'bet', ',', 'you', "'ve", 'never', 'been', 'to', 'a', 'party', 'as', 'grand', 'as', 'this', 'one', 'before', '!', "''"]
# ['``', 'You', 'bet', '!']
# ['The', 'others', 'does', "n't", 'even', 'look', 'like', 'parties', 'now', '.', "''"]
# ['``', 'The', 'biggest', 'surprise', 'is', 'not', 'yet', 'here', '.']
# ['Everything', 'you', 'see', 'now', 'pales', 'in', 'comparison', '.', "''"]
# ['``', 'Oh', 'still', 'something', 'bigger', 'is', 'left', '?', "''"]
# ['``', 'Much', 'much', 'bigger', ',', 'something', 'you', 'have', 'never', 'imagined', '!', "''"]
# ['``', 'Oh', 'what', 'could', 'that', 'be', '?']
# ['I', 'know', ',', 'I', 'know', ',', 'the', 'hand', 'of', 'the', 'princess', '!']
# ['Oh', 'come', 'on', ',', 'I', 'can', 'not', 'settle', 'down', 'right', 'now', ',', 'I', 'love', 'being', 'a', 'hero', ',', 'but', 'since', 'you', 'insist', ',', 'I', 'will', 'think', 'on…', "''", "''", 'That', "'s", 'right', ',', 'that', "'s", 'right', ',', 'now', 'is', 'not', 'really', 'the', 'time', 'for', 'you', 'to', 'settle', ',', 'I', 'have', 'never', 'seen', 'a', 'fine', 'warrior', 'like', 'you', 'before', ',', 'you', 'have', 'plenty', 'of', 'time', 'ahead', ',', 'or', 'do', 'you', 'want', 'a', 'big', 'fat', 'tummy', 'like', 'mine', '?', "''"]
# ['``', 'Haha', 'and', 'then', 'I', 'have', 'to', 'hire', 'another', 'Hero', 'to', 'save', 'my', 'kingdom', ',', 'I', 'can', 'never', 'let', 'that', 'happen', '!']
# ['At', 'least', 'not', 'before', 'I', 'tame', 'a', 'Dragon', 'from', 'the', 'village', 'of', 'Dragon', 'Tamers', '.', "''"]
# ['``', 'Maybe', 'I', 'can', 'fund', 'your', 'adventure', 'over', 'there', ',', 'only', 'bring', 'me', '3', 'Fire', 'Dragons', 'for', 'my', 'kingdom', "'s", 'protection', '.', "''"]
# ['``', 'Sure', 'sure', '.']
# ['Why', 'not', '?']
# ['Anyway', ',', 'I', "'m", 'still', 'curious', ',', 'what', 'is', 'the', 'big', 'bang', 'thing', ',', 'that', "'s", 'coming', 'next', '?', "''"]
# ['``', 'Here', 'it', 'is', "''", ',', 'the', 'king', 'directed', 'Tal', '.']
# ['The', 'Head', 'Cook', 'arrived', ',', 'along', 'with', 'him', 'came', 'something', 'grand', '.']
# ['Everybody', 'wondered', ',', 'a', 'secret', 'dish', '?']
# ['But', 'it', 'is', 'covered', '.']
# ['Everybody', 'is', 'curious', '.']
# ['What', 'could', 'that', 'be', '!', '?']
# ['``', 'Tal', ',', 'once', 'again', 'I', "'d", 'like', 'to', 'take', 'this', 'opportunity', 'to', 'thank', 'you', ',', 'on', 'behalf', 'of', 'the', 'entire', 'kingdom', ',', 'on', 'behalf', 'of', 'my', 'entire', '65', 'million', 'subjects', ',', 'for', 'saving', 'our', 'lives', 'from', 'the', 'Evil', 'Twin-headed', 'Dragon', 'Dodura', ',', 'that', 'had', 'been', 'tormenting', 'our', 'kingdom', 'for', 'so', 'long', ',', 'even', 'our', 'beautiful', 'capital', 'city', 'of', 'Astral', 'was', 'losing', 'her', 'vibrance', ',', 'she', 'is', 'now', 'recovering', '.']
# ['And', 'it', "'s", 'all', 'because', 'of', 'you', '.', "''"]
# ['Everybody', 'looked', 'at', 'Tal', '.']
# ['He', 'was', 'the', 'center', 'of', 'undivided', 'attention', '.']
# ['``', 'I', 'know', 'words', 'are', 'not', 'enough', '.']
# ['So', 'I', 'wanted', 'to', 'give', 'you', 'this', '.']
# ['The', 'rarest', 'and', 'the', 'most', 'delicious', 'fruit', 'you', "'ll", 'find', 'in', 'the', 'entire', 'world', '.']
# ['Fruit', 'that', 'does', "n't", 'rot', 'in', '100', 'years', ',', 'that', 'cures', 'incurable', 'diseases', ',', 'also', 'is', 'unbelievably', 'delicious', ',', 'only', 'those', 'who', 'have', 'tasted', 'can', 'confirm', '.']
# ['Only', 'a', 'handful', 'of', 'them', ',', 'that', 'our', 'former', 'Great', 'General', 'Snorz', 'laid', 'down', 'his', 'life', 'to', 'secure', 'from', 'the', 'treacherous', 'Southern', 'islands', ',', 'and', 'this', 'is', 'the', 'last', 'one', 'remaining', '.', "''"]
# ['Everybody', 'listened', 'to', 'the', 'king', 'with', 'awe', '.']
# ['The', 'king', 'concluded', ',', 'ordering', 'the', 'Head', 'Cook', 'to', 'remove', 'the', 'cover', '.']
# ['``', 'Tal', ',', 'I', 'want', 'you', 'to', 'have', 'it', '.']
# ['Behold', ',', 'the', 'rarest', 'of', 'the', 'rare', ',', 'The', 'Mystic', 'Pomegranite', '!', "''"]
# ['Everybody', 'looked', 'with', 'complete', 'attention', 'as', 'the', 'Head', 'Cook', 'removed', 'the', 'cover', '.']
# ['Then', 'they', 'were', 'little', 'bit', 'startled', '.']
# ['They', 'were', 'confused', '!']
# ['Really', '?']
# ['The', 'king', "'s", 'face', 'looked', 'lifeless', ',', 'stoic', '.']
# ['Head', 'Cook', 'is', 'silent', '.']
# ['They', 'were', 'all', 'looking', 'at', 'the', 'plate', '.']
# ['It', "'s", 'empty', '!']
# ['People', 'at', 'the', 'back', 'started', 'gossiping', '.']
# ['``', 'What', 'happened', '!', '?']
# ['What', 'happened', 'to', 'the', 'fruit', '?', "''"]
# ['``', 'Somebody', 'stole', 'the', 'fruit', '!']
# ['Really', '?', "''"]
# ['``', 'Mystic', 'Pomegranite', '?']
# ['A', 'miracle', 'fruit', '!', '?']
# ['Never', 'heard', 'of', 'it', '.', "''"]
# ['``', 'The', 'General', 'laid', 'down', 'his', 'life', 'for', 'a', 'stupid', 'fruit', '?']
# ['I', 'thought', 'it', 'was…', "''", "''", 'I', "'m", 'sure', 'it', "'s", 'the', 'Head', 'Cook', '.']
# ['Look', 'at', 'his', 'face', '.']
# ['The', 'fruit', 'is', 'so', 'great', ',', 'who', "wouldn't…", "''", "''", 'Feel', 'so', 'bad', 'for', 'The', 'Hero', '.']
# ['The', 'king', 'is…', "''", 'The', 'king', 'was', 'looking', 'at', 'the', 'plate', 'with', 'lifeless', 'eyes', '.']
# ['Now', 'he', 'looked', 'at', 'the', 'crowd', '.']
# ['He', 'looked', 'angry', '.']
# ['The', 'crowd', 'became', 'silent', 'in', 'an', 'instant', '.']
# ['The', 'king', 'moved', 'his', 'face', 'towards', 'the', 'Head', 'Cook', ',', 'he', "'s", 'standing', 'silent', 'with', 'eyes', 'closed', '.']
# ['The', 'Hero', 'observed', 'the', 'whole', 'situation', '.']
# ['He', 'felt', 'awkward', '.']
# ['``', 'Head', 'Cook', "''", ',', 'the', 'king', 'called', 'in', 'a', 'low', 'deep', 'voice', '.']
# ['``', 'At', 'your', 'service', ',', 'your', 'Highness', '!', "''"]
# ['``', 'Please', 'explain', '.', "''"]
# ['``', 'Yes', '!']
# ['Welcome', 'Tal', ',', 'my', 'Hero', ',', 'to', 'our', 'beautiful', 'kingdom', 'of', 'Purplewoods', ',', 'south', 'of', 'the', 'beautiful', 'Purplewoods', 'Forest', ',', 'ruled', 'by', 'his', 'Majesty', ',', 'the', 'mighty', 'king', 'Thoros', '.']
# ['In', 'the', 'name', 'of', 'his', 'highness', 'let', 'me', 'introduce', 'you', 'our', 'kingdom', "'s", 'finest', 'cuisine', '.', "''"]
# ['The', 'king', 'observed', 'the', 'situation', ',', 'but', 'stayed', 'silent', '.']
# ['The', 'Head', 'Cook', 'took', 'a', 'mug', 'of', 'wine', '.']
# ['``', 'The', 'Purple', 'Wine', ',', 'made', 'from', 'the', 'juice', 'of', 'the', 'finest', 'quality', 'purple', 'grapes', ',', 'that', 'you', 'may', 'have', 'already', 'started', 'with', ',', 'all', 'made', 'under', 'my', 'direct', 'oversight', '.']
# ['Then', 'comes', 'Fire', 'Chicken', ',', 'do', "n't", 'confuse', 'this', 'with', 'regular', 'chickens', ',', 'they', "'re", 'the', 'finest', 'breed', 'of', 'chickens', 'imported', 'from', 'the', 'Western', 'kingdoms', ',', 'I', 'have', 'made', 'it', 'personally', 'with', 'my', 'hands', '.']
# ['Once', 'you', 'eat', ',', 'you', "'ll", 'keep', 'coming', 'back', '.']
# ['Then…', "''", "''", 'Silence', "''", ',', 'the', 'king', 'shouted', 'at', 'the', 'Head', 'Cook', '.']
# ['Everybody', 'in', 'the', 'hall', 'had', 'their', 'faces', 'pale', 'in', 'fear', '.']
# ['The', 'Hero', 'was', 'observing', 'the', 'whole', 'situation', ',', 'trying', 'to', 'be', 'calm', ',', 'but', 'feeling', 'awkward', '.']
# ['``', 'Where', 'is', 'the', 'Mystic', 'Pomegranite', '!', '?', "''"]
# ['The', 'Head', 'Cook', 'stayed', 'silent', '.']
# ['``', 'It', 'was', 'your', 'responsibility', 'to', 'keep', 'it', 'safe', ',', 'and', 'bring', 'it', 'for', 'Tal', '.']
# ['Where', 'is', 'it', '?', "''"]
# ['The', 'king', "'s", 'eyes', 'turned', 'blood-red', '.']
# ['The', 'crowd', 'wondered', 'about', 'the', 'situation', ',', 'but', 'scared', 'to', 'gossip', 'about', 'anything', '.']
# ['``', 'Your', 'Highness', "''", ',', 'the', 'head', 'cook', 'said', '.']
# ['The', 'king', 'stared', 'at', 'him', '.']
# ['``', 'I', "'m", 'deeply', 'saddened', 'to', 'see', 'that', 'the', 'Wonder', 'Fruit', 'has', 'gone', 'missing', '.']
# ['At', 'your', 'direction', 'I', 'will', 'quickly', 'direct', 'the', 'cooks', 'to', 'search', 'for', 'it', "''", ',', 'the', 'head', 'cook', 'said', 'in', 'a', 'calm', 'and', 'quiet', 'tone', '.']
# ['It', 'was', 'pretty', 'apparent', 'that', 'he', 'was', 'trying', 'to', 'mock', 'the', 'king', '.']
# ['But', 'why', '!', '?']
# ['Everybody', 'wondered', '.']
# ['``', 'What', 'nonsense', '!', '?']
# ['It', "'s", 'not', 'only', 'the', 'cooks', ',', 'I', "'ll", 'also', 'direct', 'the', 'soldiers', 'to', 'search', 'for', 'it', '.']
# ['Guards', ',', 'search', 'every', 'nook', 'and', 'corner', 'of', 'the', 'Castle', 'and', 'find', 'the', 'Miracle', 'Fruit', ',', 'the', 'Mystic', 'Pomegranite', 'for', 'our', 'hero', 'ASAP', "''", ',', 'the', 'king', 'directed', '.']
# ['His', 'voice', 'echoed', 'in', 'the', 'walls', 'of', 'the', 'giant', 'hall', '.']
# ['The', 'cooks', 'and', 'the', 'guards', 'immediately', 'started', 'moving', 'around', 'in', 'search', 'of', 'the', 'fruit', '.']
# ['They', 'were', 'searching', 'everywhere', 'possible', ',', 'in', 'the', 'kitchen', ',', 'armory', ',', 'bathhouse', ',', 'below', 'mats', ',', 'behind', 'furnitures', 'and', 'other', 'decorations', ',', 'some', 'were', 'also', 'asking', 'and', 'searching', 'people', 'in', 'the', 'Castle', '.']
# ['On', 'the', 'other', 'hand', 'the', 'people', 'who', 'came', 'to', 'the', 'Castle', 'were', 'all', 'in', 'a', 'state', 'of', 'shock', 'and', 'panic', '.']
# ['Everybody', 'started', 'talking', ',', 'nobody', "'s", 'sure', 'what', "'s", 'going', 'on', '.']
# ['``', 'Better', 'I', 'should', 'also', 'assist', 'the', 'young', 'cooks', 'in', 'the', 'Great', 'Search', "''", ',', 'the', 'head', 'cook', 'said', 'as', 'he', 'wanted', 'to', 'go', 'and', 'search', '.']
# ['``', 'Shut', 'Up', 'Head', 'Cook', '!']
# ['You', "'re", 'not', 'going', 'anywhere', ',', 'unless', 'I', 'wish', 'so', "''", ',', 'the', 'king', 'noticed', 'the', 'Head', 'Cook', "'s", 'intent', 'and', 'stopped', 'him', 'immediately', '.']
# ['``', 'At', 'your', 'service', 'your', 'Highness', "''", ',', 'the', 'Cook', 'said', '.']
# ['He', 'was', 'surprisingly', 'calm', 'in', 'such', 'a', 'tense', 'situation', '.']

# %% [markdown]
# ## Stemming
#
# Reduces a word to its stem (base)
#
# #### Types
# 1. PorterStemmer
# 2. RegexpStemmer
# 3. SnowballStemmer

# %%
from nltk.stem import PorterStemmer, RegexpStemmer, SnowballStemmer

# %%
words = ["saving", "eating", "drinking", "singing", "dancing", "surrounding", "possibly", "offered", "unbothered"]

# %%
porter_stemmer = PorterStemmer()

for word in words:
    word_stem = porter_stemmer.stem(word)
    print(word + " ---> " + word_stem)
# Out:
# saving ---> save
# eating ---> eat
# drinking ---> drink
# singing ---> sing
# dancing ---> danc
# surrounding ---> surround
# possibly ---> possibl
# offered ---> offer
# unbothered ---> unboth

# %%
regexp_stemmer = RegexpStemmer('ing$|ed$', min=4)

for word in words:
    word_stem = regexp_stemmer.stem(word)
    print(word + " ---> " + word_stem)
# Out:
# saving ---> sav
# eating ---> eat
# drinking ---> drink
# singing ---> sing
# dancing ---> danc
# surrounding ---> surround
# possibly ---> possibly
# offered ---> offer
# unbothered ---> unbother

# %%
snowball_stemmer = SnowballStemmer("english")

for word in words:
    word_stem = porter_stemmer.stem(word)
    print(word + " ---> " + word_stem)
# Out:
# saving ---> save
# eating ---> eat
# drinking ---> drink
# singing ---> sing
# dancing ---> danc
# surrounding ---> surround
# possibly ---> possibl
# offered ---> offer
# unbothered ---> unboth
