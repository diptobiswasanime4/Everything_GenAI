# %% [markdown]
# # Natural Language Processing (NLP)
# ## Terminologies
#
# #### Corpus
# It is an essay (body of text)
# #### Documents
# It is the list of sentences from the essay.
# #### Words
# It is the list of words from a sentence (or essay)
# #### Tokens
# It is the list of sentences or words (tokens) from the essay

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize, wordpunct_tokenize

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dipto\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
corpus = """
The Hero, the King, and the Cook
"Tal, I'm so happy to see you here. I cannot thank you enough for saving my kingdom, we're all safe because of you. You're the true Hero!"
"Yeah it was a predicament for sure. Somebody had to do it. I did it. Haha"
"You're as cheerful as ever. Tal, I don't think it's enough, but in your honor I have decided to throw the biggest party you've ever seen. Eat, drink and party as much as you want, don't hesitate!"
"Cheers, for the kingdom, and for the king!"
The Hero and the King were seated side by side at the center of a giant hall, eating and drinking from a hundred dishes exhibited right in front of them in a giant table.
A lot of very very important people (VVIPs) were surrounding them, ministers, bureaucrats, priests, scholars, merchants, all trying to get a glimpse of the Hero, possibly talk to him. Everybody was in total awe, some even offered the hand of their daughter, the Hero was cheerful but unbothered.
Outside even the commoners were in a festive mood. They were all singing praises of the hero, and dancing. Many offered big discounts in their shops, while some hiked prices and bagged profits, all in the Hero's honor.
"Tal, what do you think? I bet, you've never been to a party as grand as this one before!"
"You bet! The others doesn't even look like parties now."
"The biggest surprise is not yet here. Everything you see now pales in comparison."
"Oh still something bigger is left?"
"Much much bigger, something you have never imagined!"
"Oh what could that be? I know, I know, the hand of the princess! Oh come on, I cannot settle down right now, I love being a hero, but since you insist, I will think on…"
"That's right, that's right, now is not really the time for you to settle, I have never seen a fine warrior like you before, you have plenty of time ahead, or do you want a big fat tummy like mine?"
"Haha and then I have to hire another Hero to save my kingdom, I can never let that happen! At least not before I tame a Dragon from the village of Dragon Tamers."
"Maybe I can fund your adventure over there, only bring me 3 Fire Dragons for my kingdom's protection."
"Sure sure. Why not? Anyway, I'm still curious, what is the big bang thing, that's coming next?"
"Here it is", the king directed Tal.
The Head Cook arrived, along with him came something grand. Everybody wondered, a secret dish? But it is covered. Everybody is curious. What could that be!?
"Tal, once again I'd like to take this opportunity to thank you, on behalf of the entire kingdom, on behalf of my entire 65 million subjects, for saving our lives from the Evil Twin-headed Dragon Dodura, that had been tormenting our kingdom for so long, even our beautiful capital city of Astral was losing her vibrance, she is now recovering. And it's all because of you."
Everybody looked at Tal. He was the center of undivided attention.
"I know words are not enough. So I wanted to give you this. The rarest and the most delicious fruit you'll find in the entire world. Fruit that doesn't rot in 100 years, that cures incurable diseases, also is unbelievably delicious, only those who have tasted can confirm. Only a handful of them, that our former Great General Snorz laid down his life to secure from the treacherous Southern islands, and this is the last one remaining."
Everybody listened to the king with awe. The king concluded, ordering the Head Cook to remove the cover.
"Tal, I want you to have it. Behold, the rarest of the rare, The Mystic Pomegranite!"
Everybody looked with complete attention as the Head Cook removed the cover. Then they were little bit startled. They were confused! Really? The king's face looked lifeless, stoic. Head Cook is silent. They were all looking at the plate. It's empty!
People at the back started gossiping.
"What happened!? What happened to the fruit?"
"Somebody stole the fruit! Really?"
"Mystic Pomegranite? A miracle fruit!? Never heard of it."
"The General laid down his life for a stupid fruit? I thought it was…"
"I'm sure it's the Head Cook. Look at his face. The fruit is so great, who wouldn't…"
"Feel so bad for The Hero. The king is…"
The king was looking at the plate with lifeless eyes. Now he looked at the crowd. He looked angry. The crowd became silent in an instant. The king moved his face towards the Head Cook, he's standing silent with eyes closed.
The Hero observed the whole situation. He felt awkward.
"Head Cook", the king called in a low deep voice.
"At your service, your Highness!"
"Please explain."
"Yes! Welcome Tal, my Hero, to our beautiful kingdom of Purplewoods, south of the beautiful Purplewoods Forest, ruled by his Majesty, the mighty king Thoros. In the name of his highness let me introduce you our kingdom's finest cuisine."
The king observed the situation, but stayed silent.
The Head Cook took a mug of wine. "The Purple Wine, made from the juice of the finest quality purple grapes, that you may have already started with, all made under my direct oversight. Then comes Fire Chicken, don't confuse this with regular chickens, they're the finest breed of chickens imported from the Western kingdoms, I have made it personally with my hands. Once you eat, you'll keep coming back. Then…"
"Silence", the king shouted at the Head Cook. Everybody in the hall had their faces pale in fear. The Hero was observing the whole situation, trying to be calm, but feeling awkward.
"Where is the Mystic Pomegranite!?"
The Head Cook stayed silent.
"It was your responsibility to keep it safe, and bring it for Tal. Where is it?"
The king's eyes turned blood-red. The crowd wondered about the situation, but scared to gossip about anything.
"Your Highness", the head cook said.
The king stared at him.
"I'm deeply saddened to see that the Wonder Fruit has gone missing. At your direction I will quickly direct the cooks to search for it", the head cook said in a calm and quiet tone. It was pretty apparent that he was trying to mock the king. But why!? Everybody wondered.
"What nonsense!? It's not only the cooks, I'll also direct the soldiers to search for it. Guards, search every nook and corner of the Castle and find the Miracle Fruit, the Mystic Pomegranite for our hero ASAP", the king directed. His voice echoed in the walls of the giant hall. The cooks and the guards immediately started moving around in search of the fruit. They were searching everywhere possible, in the kitchen, armory, bathhouse, below mats, behind furnitures and other decorations, some were also asking and searching people in the Castle. On the other hand the people who came to the Castle were all in a state of shock and panic. Everybody started talking, nobody's sure what's going on.
"Better I should also assist the young cooks in the Great Search", the head cook said as he wanted to go and search.
"Shut Up Head Cook! You're not going anywhere, unless I wish so", the king noticed the Head Cook's intent and stopped him immediately.
"At your service your Highness", the Cook said. He was surprisingly calm in such a tense situation.
"""

# %%
sentences = sent_tokenize(corpus)

# sentences

# %%
words = word_tokenize(corpus)

# words

# %%
words_punct = wordpunct_tokenize(corpus)

# words_punct

# %%
for sentence in sentences:
    word = word_tokenize(sentence)
    #print(word)

# %% [markdown]
# ## Stemming
#
# Reduces a word to its stem (base)
#
# #### Types
# 1. PorterStemmer
# 2. RegexpStemmer
# 3. SnowballStemmer

# %%
from nltk.stem import PorterStemmer, RegexpStemmer, SnowballStemmer

# %%
words = ["saving", "eating", "drinking", "singing", "dancing", "surrounding", "possibly", "offered", "unbothered"]

# %%
porter_stemmer = PorterStemmer()

for word in words:
    word_stem = porter_stemmer.stem(word)
    print(word + " ---> " + word_stem)
# Out:
# saving ---> save
# eating ---> eat
# drinking ---> drink
# singing ---> sing
# dancing ---> danc
# surrounding ---> surround
# possibly ---> possibl
# offered ---> offer
# unbothered ---> unboth

# %%
regexp_stemmer = RegexpStemmer('ing$|ed$', min=4)

for word in words:
    word_stem = regexp_stemmer.stem(word)
    print(word + " ---> " + word_stem)
# Out:
# saving ---> sav
# eating ---> eat
# drinking ---> drink
# singing ---> sing
# dancing ---> danc
# surrounding ---> surround
# possibly ---> possibly
# offered ---> offer
# unbothered ---> unbother

# %%
snowball_stemmer = SnowballStemmer("english")

for word in words:
    word_stem = snowball_stemmer.stem(word)
    print(word + " ---> " + word_stem)
# Out:
# saving ---> save
# eating ---> eat
# drinking ---> drink
# singing ---> sing
# dancing ---> danc
# surrounding ---> surround
# possibly ---> possibl
# offered ---> offer
# unbothered ---> unboth

# %% [markdown]
# ## Lemmatization
#
# Converts a word to its root (not stem). It is also called lemma.
#
# It checks the word from a dictionary (WordNet) to get the results. Hence Lemmatization is more costly than Stemming.
#
# We can also set Parts of Speech (POS) in analysis

# %%
from nltk.stem import WordNetLemmatizer

# %%
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\dipto\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
lemmatizer = WordNetLemmatizer()

# noun-n
# verb-v
# adverb-r

for word in words:
    lemma = lemmatizer.lemmatize(word, pos="v")
    print(word + " ---> " + lemma)
# Out:
# saving ---> save
# eating ---> eat
# drinking ---> drink
# singing ---> sing
# dancing ---> dance
# surrounding ---> surround
# possibly ---> possibly
# offered ---> offer
# unbothered ---> unbothered

# %% [markdown]
# ## Stopwords
#
# Collection of generic (not so important) words.
#
# These words can be removed from corpus for increased efficiency (and decreased accuracy but less)

# %%
from nltk.corpus import stopwords

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dipto\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords_en = stopwords.words("english")

stopwords_en
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  'shouldn',
#  "shouldn't",
#  "should've",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  'were',
#  'weren',
#  "weren't",
#  "we've",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  'your',
#  "you're",
#  'yours',
#  'yourself',
#  'yourselves',
#  "you've"]

# %%
good_words = []

for word in words:
    if word not in stopwords_en:
        good_words.append(word)
        
# print(good_words)

# %%
for sentence in sentences:
    word_tokens = word_tokenize(sentence)
    good_words = []
    for word in word_tokens:
        if word not in stopwords_en:
            good_words.append(word)
    #print(good_words)

# %%
for sentence in sentences:
    word_tokens = word_tokenize(sentence)
    good_words_stem = []
    good_words_lemma = []
    for word in word_tokens:
        if word not in stopwords_en:
            word_stem = porter_stemmer.stem(word)
            word_lemma = lemmatizer.lemmatize(word, pos="v")
            good_words_stem.append(word_stem)
            good_words_lemma.append(word_lemma)
    print(good_words_stem)
    print(good_words_lemma)
# Out:
# ['the', 'hero', ',', 'king', ',', 'cook', "''", 'tal', ',', 'i', "'m", 'happi', 'see', '.']
# ['The', 'Hero', ',', 'King', ',', 'Cook', "''", 'Tal', ',', 'I', "'m", 'happy', 'see', '.']
# ['i', 'thank', 'enough', 'save', 'kingdom', ',', "'re", 'safe', '.']
# ['I', 'thank', 'enough', 'save', 'kingdom', ',', "'re", 'safe', '.']
# ['you', "'re", 'true', 'hero', '!', "''"]
# ['You', "'re", 'true', 'Hero', '!', "''"]
# ['``', 'yeah', 'predica', 'sure', '.']
# ['``', 'Yeah', 'predicament', 'sure', '.']
# ['somebodi', '.']
# ['Somebody', '.']
# ['i', '.']
# ['I', '.']
# ['haha', "''", "''", 'you', "'re", 'cheer', 'ever', '.']
# ['Haha', "''", "''", 'You', "'re", 'cheerful', 'ever', '.']
# ['tal', ',', 'i', "n't", 'think', "'s", 'enough', ',', 'honor', 'i', 'decid', 'throw', 'biggest', 'parti', "'ve", 'ever', 'seen', '.']
# ['Tal', ',', 'I', "n't", 'think', "'s", 'enough', ',', 'honor', 'I', 'decide', 'throw', 'biggest', 'party', "'ve", 'ever', 'see', '.']
# ['eat', ',', 'drink', 'parti', 'much', 'want', ',', "n't", 'hesit', '!', "''"]
# ['Eat', ',', 'drink', 'party', 'much', 'want', ',', "n't", 'hesitate', '!', "''"]
# ['``', 'cheer', ',', 'kingdom', ',', 'king', '!', "''"]
# ['``', 'Cheers', ',', 'kingdom', ',', 'king', '!', "''"]
# ['the', 'hero', 'king', 'seat', 'side', 'side', 'center', 'giant', 'hall', ',', 'eat', 'drink', 'hundr', 'dish', 'exhibit', 'right', 'front', 'giant', 'tabl', '.']
# ['The', 'Hero', 'King', 'seat', 'side', 'side', 'center', 'giant', 'hall', ',', 'eat', 'drink', 'hundred', 'dish', 'exhibit', 'right', 'front', 'giant', 'table', '.']
# ['a', 'lot', 'import', 'peopl', '(', 'vvip', ')', 'surround', ',', 'minist', ',', 'bureaucrat', ',', 'priest', ',', 'scholar', ',', 'merchant', ',', 'tri', 'get', 'glimps', 'hero', ',', 'possibl', 'talk', '.']
# ['A', 'lot', 'important', 'people', '(', 'VVIPs', ')', 'surround', ',', 'minister', ',', 'bureaucrats', ',', 'priests', ',', 'scholars', ',', 'merchants', ',', 'try', 'get', 'glimpse', 'Hero', ',', 'possibly', 'talk', '.']
# ['everybodi', 'total', 'awe', ',', 'even', 'offer', 'hand', 'daughter', ',', 'hero', 'cheer', 'unboth', '.']
# ['Everybody', 'total', 'awe', ',', 'even', 'offer', 'hand', 'daughter', ',', 'Hero', 'cheerful', 'unbothered', '.']
# ['outsid', 'even', 'common', 'festiv', 'mood', '.']
# ['Outside', 'even', 'commoners', 'festive', 'mood', '.']
# ['they', 'sing', 'prais', 'hero', ',', 'danc', '.']
# ['They', 'sing', 'praise', 'hero', ',', 'dance', '.']
# ['mani', 'offer', 'big', 'discount', 'shop', ',', 'hike', 'price', 'bag', 'profit', ',', 'hero', "'s", 'honor', '.']
# ['Many', 'offer', 'big', 'discount', 'shop', ',', 'hike', 'price', 'bag', 'profit', ',', 'Hero', "'s", 'honor', '.']
# ['``', 'tal', ',', 'think', '?']
# ['``', 'Tal', ',', 'think', '?']
# ['i', 'bet', ',', "'ve", 'never', 'parti', 'grand', 'one', '!', "''"]
# ['I', 'bet', ',', "'ve", 'never', 'party', 'grand', 'one', '!', "''"]
# ['``', 'you', 'bet', '!']
# ['``', 'You', 'bet', '!']
# ['the', 'other', "n't", 'even', 'look', 'like', 'parti', '.', "''"]
# ['The', 'others', "n't", 'even', 'look', 'like', 'party', '.', "''"]
# ['``', 'the', 'biggest', 'surpris', 'yet', '.']
# ['``', 'The', 'biggest', 'surprise', 'yet', '.']
# ['everyth', 'see', 'pale', 'comparison', '.', "''"]
# ['Everything', 'see', 'pal', 'comparison', '.', "''"]
# ['``', 'oh', 'still', 'someth', 'bigger', 'left', '?', "''"]
# ['``', 'Oh', 'still', 'something', 'bigger', 'leave', '?', "''"]
# ['``', 'much', 'much', 'bigger', ',', 'someth', 'never', 'imagin', '!', "''"]
# ['``', 'Much', 'much', 'bigger', ',', 'something', 'never', 'imagine', '!', "''"]
# ['``', 'oh', 'could', '?']
# ['``', 'Oh', 'could', '?']
# ['i', 'know', ',', 'i', 'know', ',', 'hand', 'princess', '!']
# ['I', 'know', ',', 'I', 'know', ',', 'hand', 'princess', '!']
# ['oh', 'come', ',', 'i', 'settl', 'right', ',', 'i', 'love', 'hero', ',', 'sinc', 'insist', ',', 'i', 'think', 'on…', "''", "''", 'that', "'s", 'right', ',', "'s", 'right', ',', 'realli', 'time', 'settl', ',', 'i', 'never', 'seen', 'fine', 'warrior', 'like', ',', 'plenti', 'time', 'ahead', ',', 'want', 'big', 'fat', 'tummi', 'like', 'mine', '?', "''"]
# ['Oh', 'come', ',', 'I', 'settle', 'right', ',', 'I', 'love', 'hero', ',', 'since', 'insist', ',', 'I', 'think', 'on…', "''", "''", 'That', "'s", 'right', ',', "'s", 'right', ',', 'really', 'time', 'settle', ',', 'I', 'never', 'see', 'fine', 'warrior', 'like', ',', 'plenty', 'time', 'ahead', ',', 'want', 'big', 'fat', 'tummy', 'like', 'mine', '?', "''"]
# ['``', 'haha', 'i', 'hire', 'anoth', 'hero', 'save', 'kingdom', ',', 'i', 'never', 'let', 'happen', '!']
# ['``', 'Haha', 'I', 'hire', 'another', 'Hero', 'save', 'kingdom', ',', 'I', 'never', 'let', 'happen', '!']
# ['at', 'least', 'i', 'tame', 'dragon', 'villag', 'dragon', 'tamer', '.', "''"]
# ['At', 'least', 'I', 'tame', 'Dragon', 'village', 'Dragon', 'Tamers', '.', "''"]
# ['``', 'mayb', 'i', 'fund', 'adventur', ',', 'bring', '3', 'fire', 'dragon', 'kingdom', "'s", 'protect', '.', "''"]
# ['``', 'Maybe', 'I', 'fund', 'adventure', ',', 'bring', '3', 'Fire', 'Dragons', 'kingdom', "'s", 'protection', '.', "''"]
# ['``', 'sure', 'sure', '.']
# ['``', 'Sure', 'sure', '.']
# ['whi', '?']
# ['Why', '?']
# ['anyway', ',', 'i', "'m", 'still', 'curiou', ',', 'big', 'bang', 'thing', ',', "'s", 'come', 'next', '?', "''"]
# ['Anyway', ',', 'I', "'m", 'still', 'curious', ',', 'big', 'bang', 'thing', ',', "'s", 'come', 'next', '?', "''"]
# ['``', 'here', "''", ',', 'king', 'direct', 'tal', '.']
# ['``', 'Here', "''", ',', 'king', 'direct', 'Tal', '.']
# ['the', 'head', 'cook', 'arriv', ',', 'along', 'came', 'someth', 'grand', '.']
# ['The', 'Head', 'Cook', 'arrive', ',', 'along', 'come', 'something', 'grand', '.']
# ['everybodi', 'wonder', ',', 'secret', 'dish', '?']
# ['Everybody', 'wonder', ',', 'secret', 'dish', '?']
# ['but', 'cover', '.']
# ['But', 'cover', '.']
# ['everybodi', 'curiou', '.']
# ['Everybody', 'curious', '.']
# ['what', 'could', '!', '?']
# ['What', 'could', '!', '?']
# ['``', 'tal', ',', 'i', "'d", 'like', 'take', 'opportun', 'thank', ',', 'behalf', 'entir', 'kingdom', ',', 'behalf', 'entir', '65', 'million', 'subject', ',', 'save', 'live', 'evil', 'twin-head', 'dragon', 'dodura', ',', 'torment', 'kingdom', 'long', ',', 'even', 'beauti', 'capit', 'citi', 'astral', 'lose', 'vibranc', ',', 'recov', '.']
# ['``', 'Tal', ',', 'I', "'d", 'like', 'take', 'opportunity', 'thank', ',', 'behalf', 'entire', 'kingdom', ',', 'behalf', 'entire', '65', 'million', 'subject', ',', 'save', 'live', 'Evil', 'Twin-headed', 'Dragon', 'Dodura', ',', 'torment', 'kingdom', 'long', ',', 'even', 'beautiful', 'capital', 'city', 'Astral', 'lose', 'vibrance', ',', 'recover', '.']
# ['and', "'s", '.', "''"]
# ['And', "'s", '.', "''"]
# ['everybodi', 'look', 'tal', '.']
# ['Everybody', 'look', 'Tal', '.']
# ['he', 'center', 'undivid', 'attent', '.']
# ['He', 'center', 'undivided', 'attention', '.']
# ['``', 'i', 'know', 'word', 'enough', '.']
# ['``', 'I', 'know', 'word', 'enough', '.']
# ['so', 'i', 'want', 'give', '.']
# ['So', 'I', 'want', 'give', '.']
# ['the', 'rarest', 'delici', 'fruit', "'ll", 'find', 'entir', 'world', '.']
# ['The', 'rarest', 'delicious', 'fruit', "'ll", 'find', 'entire', 'world', '.']
# ['fruit', "n't", 'rot', '100', 'year', ',', 'cure', 'incur', 'diseas', ',', 'also', 'unbeliev', 'delici', ',', 'tast', 'confirm', '.']
# ['Fruit', "n't", 'rot', '100', 'years', ',', 'cure', 'incurable', 'diseases', ',', 'also', 'unbelievably', 'delicious', ',', 'taste', 'confirm', '.']
# ['onli', 'hand', ',', 'former', 'great', 'gener', 'snorz', 'laid', 'life', 'secur', 'treacher', 'southern', 'island', ',', 'last', 'one', 'remain', '.', "''"]
# ['Only', 'handful', ',', 'former', 'Great', 'General', 'Snorz', 'lay', 'life', 'secure', 'treacherous', 'Southern', 'islands', ',', 'last', 'one', 'remain', '.', "''"]
# ['everybodi', 'listen', 'king', 'awe', '.']
# ['Everybody', 'listen', 'king', 'awe', '.']
# ['the', 'king', 'conclud', ',', 'order', 'head', 'cook', 'remov', 'cover', '.']
# ['The', 'king', 'conclude', ',', 'order', 'Head', 'Cook', 'remove', 'cover', '.']
# ['``', 'tal', ',', 'i', 'want', '.']
# ['``', 'Tal', ',', 'I', 'want', '.']
# ['behold', ',', 'rarest', 'rare', ',', 'the', 'mystic', 'pomegranit', '!', "''"]
# ['Behold', ',', 'rarest', 'rare', ',', 'The', 'Mystic', 'Pomegranite', '!', "''"]
# ['everybodi', 'look', 'complet', 'attent', 'head', 'cook', 'remov', 'cover', '.']
# ['Everybody', 'look', 'complete', 'attention', 'Head', 'Cook', 'remove', 'cover', '.']
# ['then', 'littl', 'bit', 'startl', '.']
# ['Then', 'little', 'bite', 'startle', '.']
# ['they', 'confus', '!']
# ['They', 'confuse', '!']
# ['realli', '?']
# ['Really', '?']
# ['the', 'king', "'s", 'face', 'look', 'lifeless', ',', 'stoic', '.']
# ['The', 'king', "'s", 'face', 'look', 'lifeless', ',', 'stoic', '.']
# ['head', 'cook', 'silent', '.']
# ['Head', 'Cook', 'silent', '.']
# ['they', 'look', 'plate', '.']
# ['They', 'look', 'plate', '.']
# ['it', "'s", 'empti', '!']
# ['It', "'s", 'empty', '!']
# ['peopl', 'back', 'start', 'gossip', '.']
# ['People', 'back', 'start', 'gossip', '.']
# ['``', 'what', 'happen', '!', '?']
# ['``', 'What', 'happen', '!', '?']
# ['what', 'happen', 'fruit', '?', "''"]
# ['What', 'happen', 'fruit', '?', "''"]
# ['``', 'somebodi', 'stole', 'fruit', '!']
# ['``', 'Somebody', 'steal', 'fruit', '!']
# ['realli', '?', "''"]
# ['Really', '?', "''"]
# ['``', 'mystic', 'pomegranit', '?']
# ['``', 'Mystic', 'Pomegranite', '?']
# ['a', 'miracl', 'fruit', '!', '?']
# ['A', 'miracle', 'fruit', '!', '?']
# ['never', 'heard', '.', "''"]
# ['Never', 'hear', '.', "''"]
# ['``', 'the', 'gener', 'laid', 'life', 'stupid', 'fruit', '?']
# ['``', 'The', 'General', 'lay', 'life', 'stupid', 'fruit', '?']
# ['i', 'thought', 'was…', "''", "''", 'i', "'m", 'sure', "'s", 'head', 'cook', '.']
# ['I', 'think', 'was…', "''", "''", 'I', "'m", 'sure', "'s", 'Head', 'Cook', '.']
# ['look', 'face', '.']
# ['Look', 'face', '.']
# ['the', 'fruit', 'great', ',', "wouldn't…", "''", "''", 'feel', 'bad', 'the', 'hero', '.']
# ['The', 'fruit', 'great', ',', "wouldn't…", "''", "''", 'Feel', 'bad', 'The', 'Hero', '.']
# ['the', 'king', 'is…', "''", 'the', 'king', 'look', 'plate', 'lifeless', 'eye', '.']
# ['The', 'king', 'is…', "''", 'The', 'king', 'look', 'plate', 'lifeless', 'eye', '.']
# ['now', 'look', 'crowd', '.']
# ['Now', 'look', 'crowd', '.']
# ['he', 'look', 'angri', '.']
# ['He', 'look', 'angry', '.']
# ['the', 'crowd', 'becam', 'silent', 'instant', '.']
# ['The', 'crowd', 'become', 'silent', 'instant', '.']
# ['the', 'king', 'move', 'face', 'toward', 'head', 'cook', ',', "'s", 'stand', 'silent', 'eye', 'close', '.']
# ['The', 'king', 'move', 'face', 'towards', 'Head', 'Cook', ',', "'s", 'stand', 'silent', 'eye', 'close', '.']
# ['the', 'hero', 'observ', 'whole', 'situat', '.']
# ['The', 'Hero', 'observe', 'whole', 'situation', '.']
# ['he', 'felt', 'awkward', '.']
# ['He', 'felt', 'awkward', '.']
# ['``', 'head', 'cook', "''", ',', 'king', 'call', 'low', 'deep', 'voic', '.']
# ['``', 'Head', 'Cook', "''", ',', 'king', 'call', 'low', 'deep', 'voice', '.']
# ['``', 'at', 'servic', ',', 'high', '!', "''"]
# ['``', 'At', 'service', ',', 'Highness', '!', "''"]
# ['``', 'pleas', 'explain', '.', "''"]
# ['``', 'Please', 'explain', '.', "''"]
# ['``', 'ye', '!']
# ['``', 'Yes', '!']
# ['welcom', 'tal', ',', 'hero', ',', 'beauti', 'kingdom', 'purplewood', ',', 'south', 'beauti', 'purplewood', 'forest', ',', 'rule', 'majesti', ',', 'mighti', 'king', 'thoro', '.']
# ['Welcome', 'Tal', ',', 'Hero', ',', 'beautiful', 'kingdom', 'Purplewoods', ',', 'south', 'beautiful', 'Purplewoods', 'Forest', ',', 'rule', 'Majesty', ',', 'mighty', 'king', 'Thoros', '.']
# ['in', 'name', 'high', 'let', 'introduc', 'kingdom', "'s", 'finest', 'cuisin', '.', "''"]
# ['In', 'name', 'highness', 'let', 'introduce', 'kingdom', "'s", 'finest', 'cuisine', '.', "''"]
# ['the', 'king', 'observ', 'situat', ',', 'stay', 'silent', '.']
# ['The', 'king', 'observe', 'situation', ',', 'stay', 'silent', '.']
# ['the', 'head', 'cook', 'took', 'mug', 'wine', '.']
# ['The', 'Head', 'Cook', 'take', 'mug', 'wine', '.']
# ['``', 'the', 'purpl', 'wine', ',', 'made', 'juic', 'finest', 'qualiti', 'purpl', 'grape', ',', 'may', 'alreadi', 'start', ',', 'made', 'direct', 'oversight', '.']
# ['``', 'The', 'Purple', 'Wine', ',', 'make', 'juice', 'finest', 'quality', 'purple', 'grapes', ',', 'may', 'already', 'start', ',', 'make', 'direct', 'oversight', '.']
# ['then', 'come', 'fire', 'chicken', ',', "n't", 'confus', 'regular', 'chicken', ',', "'re", 'finest', 'breed', 'chicken', 'import', 'western', 'kingdom', ',', 'i', 'made', 'person', 'hand', '.']
# ['Then', 'come', 'Fire', 'Chicken', ',', "n't", 'confuse', 'regular', 'chickens', ',', "'re", 'finest', 'breed', 'chickens', 'import', 'Western', 'kingdoms', ',', 'I', 'make', 'personally', 'hand', '.']
# ['onc', 'eat', ',', "'ll", 'keep', 'come', 'back', '.']
# ['Once', 'eat', ',', "'ll", 'keep', 'come', 'back', '.']
# ['then…', "''", "''", 'silenc', "''", ',', 'king', 'shout', 'head', 'cook', '.']
# ['Then…', "''", "''", 'Silence', "''", ',', 'king', 'shout', 'Head', 'Cook', '.']
# ['everybodi', 'hall', 'face', 'pale', 'fear', '.']
# ['Everybody', 'hall', 'face', 'pale', 'fear', '.']
# ['the', 'hero', 'observ', 'whole', 'situat', ',', 'tri', 'calm', ',', 'feel', 'awkward', '.']
# ['The', 'Hero', 'observe', 'whole', 'situation', ',', 'try', 'calm', ',', 'feel', 'awkward', '.']
# ['``', 'where', 'mystic', 'pomegranit', '!', '?', "''"]
# ['``', 'Where', 'Mystic', 'Pomegranite', '!', '?', "''"]
# ['the', 'head', 'cook', 'stay', 'silent', '.']
# ['The', 'Head', 'Cook', 'stay', 'silent', '.']
# ['``', 'it', 'respons', 'keep', 'safe', ',', 'bring', 'tal', '.']
# ['``', 'It', 'responsibility', 'keep', 'safe', ',', 'bring', 'Tal', '.']
# ['where', '?', "''"]
# ['Where', '?', "''"]
# ['the', 'king', "'s", 'eye', 'turn', 'blood-r', '.']
# ['The', 'king', "'s", 'eye', 'turn', 'blood-red', '.']
# ['the', 'crowd', 'wonder', 'situat', ',', 'scare', 'gossip', 'anyth', '.']
# ['The', 'crowd', 'wonder', 'situation', ',', 'scar', 'gossip', 'anything', '.']
# ['``', 'your', 'high', "''", ',', 'head', 'cook', 'said', '.']
# ['``', 'Your', 'Highness', "''", ',', 'head', 'cook', 'say', '.']
# ['the', 'king', 'stare', '.']
# ['The', 'king', 'star', '.']
# ['``', 'i', "'m", 'deepli', 'sadden', 'see', 'wonder', 'fruit', 'gone', 'miss', '.']
# ['``', 'I', "'m", 'deeply', 'sadden', 'see', 'Wonder', 'Fruit', 'go', 'miss', '.']
# ['at', 'direct', 'i', 'quickli', 'direct', 'cook', 'search', "''", ',', 'head', 'cook', 'said', 'calm', 'quiet', 'tone', '.']
# ['At', 'direction', 'I', 'quickly', 'direct', 'cook', 'search', "''", ',', 'head', 'cook', 'say', 'calm', 'quiet', 'tone', '.']
# ['it', 'pretti', 'appar', 'tri', 'mock', 'king', '.']
# ['It', 'pretty', 'apparent', 'try', 'mock', 'king', '.']
# ['but', '!', '?']
# ['But', '!', '?']
# ['everybodi', 'wonder', '.']
# ['Everybody', 'wonder', '.']
# ['``', 'what', 'nonsens', '!', '?']
# ['``', 'What', 'nonsense', '!', '?']
# ['it', "'s", 'cook', ',', 'i', "'ll", 'also', 'direct', 'soldier', 'search', '.']
# ['It', "'s", 'cook', ',', 'I', "'ll", 'also', 'direct', 'soldier', 'search', '.']
# ['guard', ',', 'search', 'everi', 'nook', 'corner', 'castl', 'find', 'miracl', 'fruit', ',', 'mystic', 'pomegranit', 'hero', 'asap', "''", ',', 'king', 'direct', '.']
# ['Guards', ',', 'search', 'every', 'nook', 'corner', 'Castle', 'find', 'Miracle', 'Fruit', ',', 'Mystic', 'Pomegranite', 'hero', 'ASAP', "''", ',', 'king', 'direct', '.']
# ['hi', 'voic', 'echo', 'wall', 'giant', 'hall', '.']
# ['His', 'voice', 'echo', 'wall', 'giant', 'hall', '.']
# ['the', 'cook', 'guard', 'immedi', 'start', 'move', 'around', 'search', 'fruit', '.']
# ['The', 'cook', 'guard', 'immediately', 'start', 'move', 'around', 'search', 'fruit', '.']
# ['they', 'search', 'everywher', 'possibl', ',', 'kitchen', ',', 'armori', ',', 'bathhous', ',', 'mat', ',', 'behind', 'furnitur', 'decor', ',', 'also', 'ask', 'search', 'peopl', 'castl', '.']
# ['They', 'search', 'everywhere', 'possible', ',', 'kitchen', ',', 'armory', ',', 'bathhouse', ',', 'mat', ',', 'behind', 'furnitures', 'decorations', ',', 'also', 'ask', 'search', 'people', 'Castle', '.']
# ['on', 'hand', 'peopl', 'came', 'castl', 'state', 'shock', 'panic', '.']
# ['On', 'hand', 'people', 'come', 'Castle', 'state', 'shock', 'panic', '.']
# ['everybodi', 'start', 'talk', ',', 'nobodi', "'s", 'sure', "'s", 'go', '.']
# ['Everybody', 'start', 'talk', ',', 'nobody', "'s", 'sure', "'s", 'go', '.']
# ['``', 'better', 'i', 'also', 'assist', 'young', 'cook', 'great', 'search', "''", ',', 'head', 'cook', 'said', 'want', 'go', 'search', '.']
# ['``', 'Better', 'I', 'also', 'assist', 'young', 'cook', 'Great', 'Search', "''", ',', 'head', 'cook', 'say', 'want', 'go', 'search', '.']
# ['``', 'shut', 'up', 'head', 'cook', '!']
# ['``', 'Shut', 'Up', 'Head', 'Cook', '!']
# ['you', "'re", 'go', 'anywher', ',', 'unless', 'i', 'wish', "''", ',', 'king', 'notic', 'head', 'cook', "'s", 'intent', 'stop', 'immedi', '.']
# ['You', "'re", 'go', 'anywhere', ',', 'unless', 'I', 'wish', "''", ',', 'king', 'notice', 'Head', 'Cook', "'s", 'intent', 'stop', 'immediately', '.']
# ['``', 'at', 'servic', 'high', "''", ',', 'cook', 'said', '.']
# ['``', 'At', 'service', 'Highness', "''", ',', 'Cook', 'say', '.']
# ['he', 'surprisingli', 'calm', 'tens', 'situat', '.']
# ['He', 'surprisingly', 'calm', 'tense', 'situation', '.']
